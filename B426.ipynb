# %% [markdown]
# <a href="https://colab.research.google.com/github/Vinith467/ITvedant-assignments/blob/main/B426.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Basics
#
# I/O

# %%
# input

student_name = input("Enter your name please : ")

# output
print("Welcome to the college, Dear", student_name)
print("Welcome to the college, Dear " + student_name)
print(f"Welcome to the college, Dear {student_name}")
# Out:
# Enter your name please : Raju
# Welcome to the college, Dear Raju
# Welcome to the college, Dear Raju
# Welcome to the college, Dear Raju

# %% [markdown]
# ### Datatypes

# %%
x = 10 # int
x= 10.0 # float
x = 2 + 3j # complex

# Sequence types

x = "hello" # str

x = [1,2,3,"asdf"] # list

x = (1,2,3,4) # tuple
x = 3,2,1 # tuple
x = 2, # tuple

# Collection
x = {1, 10, 23, 4, 46, 0}
print(f"Set : {x}")

# Mapping datatype
# Dictionary
# Every key must be an immutable datatype i.e., string, int, tuple
student = {
    'name' : "Arun",
    'age' : 20
}
data = {
    1 : "asdf",
    2 : "asdfa"
}
print(student['name'])
# Out:
# Set : {0, 1, 4, 23, 10, 46}
# Arun

# %% [markdown]
# ## Example Code
#
# ###### Lets imagine a game.
# - A new user starts to play the game by providing the username and perhaps also the age.
# - Welcome the user with a warm message.

# %%
print("Welcome to the game!!!")
user_name = input("Enter your username please : ")
age = input("Enter your age : ")
print(f"""Dear {user_name},
          have a thrilling gaming experience.""")
# Out:
# Welcome to the game!!!
# Enter your username please : pavan
# Enter your age : 10
# Dear pavan,
#           have a thrilling gaming experience.

# %% [markdown]
# Version 2
# - Let's add some conditions
# - Only legally adult gamers are allowed

# %%
AGE_LIMIT = 18
print("Welcome to the game!!!")
user_name = input("Enter your username please : ")
age = int(input("Enter your age : "))

print(f"""Dear {user_name},
          have a thrilling gaming experience."""
      if age >= AGE_LIMIT else
      f"""Dear {user_name},
          you have to wait {AGE_LIMIT - age} years to play this game.
          """)
# Out:
# Welcome to the game!!!
# Enter your username please : pavan
# Enter your age : 20
# Dear pavan,
#           have a thrilling gaming experience.

# %% [markdown]
# ---
# **Now let's build something bigger...**
#
# A quiz game
#
# To start with, we need the question bank.
# - Each question must contain
#   - The question
#   - 4 choices
#   - index of the correct answer
#   - hint
#
# - Let's create a dictionary structure for the same

# %%
question_bank = [ {
    'id' : 1,
    'q' : "Some question?",
    'choices' : ['choice1', 'choice2', 'choice3', 'choice4' ],
    'correct_index' : 0,
    'hint' : "some hint"
},
]

# %% [markdown]
# Used chatGPT to generate some sample questions

# %%
question_bank = [
    {
        'id': 1,
        'q': "Which keyword is used to define a function in Python?",
        'choices': ['function', 'def', 'fun', 'define'],
        'correct_index': 1,
        'hint': "It starts with the letter 'd'."
    },
    {
        'id': 2,
        'q': "What is the correct file extension for Python files?",
        'choices': ['.py', '.pt', '.pyt', '.python'],
        'correct_index': 0,
        'hint': "Short and simple!"
    },
    {
        'id': 3,
        'q': "Which data type is mutable in Python?",
        'choices': ['Tuple', 'String', 'List', 'Integer'],
        'correct_index': 2,
        'hint': "It’s used to store multiple items and can change."
    },
    {
        'id': 4,
        'q': "Which operator is used for floor division in Python?",
        'choices': ['/', '//', '%', '**'],
        'correct_index': 1,
        'hint': "It is a double of normal division."
    },
    {
        'id': 5,
        'q': "How do you insert comments in Python?",
        'choices': ['// comment', '<!-- comment -->', '# comment', '/* comment */'],
        'correct_index': 2,
        'hint': "It starts with a hash."
    },
    {
        'id': 6,
        'q': "Which function returns the length of an object?",
        'choices': ['size()', 'count()', 'length()', 'len()'],
        'correct_index': 3,
        'hint': "Three letters, short and sweet."
    },
    {
        'id': 7,
        'q': "What type of loop is 'for' in Python?",
        'choices': ['Conditional loop', 'Recursion', 'Iterative loop', 'Switch loop'],
        'correct_index': 2,
        'hint': "It runs multiple times over items."
    },
    {
        'id': 8,
        'q': "What is the output of: print(2**3)?",
        'choices': ['6', '8', '9', '16'],
        'correct_index': 1,
        'hint': "** means power."
    },
    {
        'id': 9,
        'q': "Which keyword is used to handle exceptions in Python?",
        'choices': ['exception', 'catch', 'try', 'error'],
        'correct_index': 2,
        'hint': "It’s part of try-except."
    },
    {
        'id': 10,
        'q': "Which of these is a Python tuple?",
        'choices': ['[1, 2, 3]', '{1, 2, 3}', '(1, 2, 3)', '<1, 2, 3>'],
        'correct_index': 2,
        'hint': "It uses round brackets."
    },
    {
        'id': 11,
        'q': "What is the output of print(type(10))?",
        'choices': ['<class “float”>', '<class “str”>', '<class “int”>', '<class “list”>'],
        'correct_index': 2,
        'hint': "10 is a whole number."
    },
    {
        'id': 12,
        'q': "Which keyword is used to create a class?",
        'choices': ['struct', 'class', 'object', 'define'],
        'correct_index': 1,
        'hint': "Same as the concept name!"
    },
    {
        'id': 13,
        'q': "What does the pop() method do in lists?",
        'choices': ['Removes last item', 'Adds an item', 'Sorts list', 'Makes a copy'],
        'correct_index': 0,
        'hint': "It removes from the end by default."
    },
    {
        'id': 14,
        'q': "Which built-in function converts a value to a string?",
        'choices': ['str()', 'string()', 'txt()', 'toString()'],
        'correct_index': 0,
        'hint': "Just 3 letters."
    },
    {
        'id': 15,
        'q': "Which symbol is used to import modules?",
        'choices': ['#', '@', 'import', '$'],
        'correct_index': 2,
        'hint': "The keyword is literally the action you are doing."
    },
    {
        'id': 16,
        'q': "Which data structure stores key-value pairs?",
        'choices': ['List', 'Tuple', 'Dictionary', 'Set'],
        'correct_index': 2,
        'hint': "Also called a map in some languages."
    },
    {
        'id': 17,
        'q': "Which function is used to take user input?",
        'choices': ['read()', 'scan()', 'get()', 'input()'],
        'correct_index': 3,
        'hint': "It asks for input from a user."
    },
    {
        'id': 18,
        'q': "What is the Boolean value of 0 in Python?",
        'choices': ['True', 'False', 'None', 'Undefined'],
        'correct_index': 1,
        'hint': "Zero means no value."
    },
    {
        'id': 19,
        'q': "What is used to define a block of code in Python?",
        'choices': ['Braces {}', 'Semicolon ;', 'Indentation', 'Parentheses ()'],
        'correct_index': 2,
        'hint': "Whitespaces matter in Python."
    },
    {
        'id': 20,
        'q': "Which statement is used to stop a loop?",
        'choices': ['stop', 'exit', 'break', 'end'],
        'correct_index': 2,
        'hint': "Break the loop!"
    },
]

# %%
# functions to handle the question bank
QUESTION_BANK_FILE_NAME = 'questions.json'

def questions_to_file(question_bank, file_name):
  """
  This function writes the given question bank to the provided file_name
  in JSON format.
  """
  import json
  with open(file_name, 'w') as questions_file:
    json.dump(question_bank, questions_file, indent=4)

questions_to_file(question_bank, QUESTION_BANK_FILE_NAME)


q21 = {
    'id': 21,
    'q': "Which method is used to add an element at the end of a list in Python?",
    'choices': ['append()', 'add()', 'insert()', 'push()'],
    'correct_index': 0,
    'hint': "It appends the item to the list."
}

def read_questions_from_file(file_name):
  """
  Reads question bank from the provided json file to the global question_bank
  variable.
  """
  import json
  with open(file_name, 'r') as questions_file:
    global question_bank
    question_bank = json.load(questions_file)
    # this converts and returns the list of dictionary structure into memory
  return question_bank

# I want to add this to the file
def add_question_to_file(question, file_name):
  """
  Appends a new question into the file as well as updates the
  global question_bank variable in the process.

  Question must be of format :
  {
    'id' : 1,
    'q' : "Some question?",
    'choices' : ['choice1', 'choice2', 'choice3', 'choice4' ],
    'correct_index' : 0,
    'hint' : "some hint"
  },
  """

  # 1. Read existing file
  read_questions_from_file(file_name)
  # overwrites the global question bank from file

  # 2. Append the new dictionary
  global question_bank
  question_bank.append(question)
  # 3. Write back new list to json file
  questions_to_file(question_bank, file_name)

add_question_to_file(q21, QUESTION_BANK_FILE_NAME)

# %%
def main_menu():
  prompt = """
  Please select your choice:
  1. View question bank
  2. Add question
  0. Exit
  """
  choice = input(prompt)
  try:
    choice = int(choice)
  except ValueError:
    print("Please check your input")
    main_menu()

  match choice:
    case 0:
      print("Exiting")
    case 1:
      print("Here is the question bank")
    case 2:
      print("Let's add a new question")
    case _:
      print("Invalid choice")
      main_menu()

main_menu()
# Out:
#   Please select your choice:
#   1. View question bank
#   2. Add question
#   0. Exit
#   1
# Here is the question bank

# %%
class Question:
  def __init__(self, q, choices, correct_index, hint):
    self.q = q
    self.choices = choices
    self.correct_index = correct_index
    self.hint = hint

  def __str__(self):
    return f"""Question : {self.q}
  Choices :
      {self.choices}
  Hint : {self.hint}
    """


q = Question('What is your name ?', ['ac', 'as', 'sc','asdf'], 2, 'You know it')
print(q)
print(q.__dict__)
# Out:
# Question : What is your name ?
#   Choices :
#       ['ac', 'as', 'sc', 'asdf']
#   Hint : You know it
#
# {'q': 'What is your name ?', 'choices': ['ac', 'as', 'sc', 'asdf'], 'correct_index': 2, 'hint': 'You know it'}
